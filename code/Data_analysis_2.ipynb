# %%
import pandas as pd

# %%
cat = pd.read_csv('data/product-categories.csv', sep=';')
cat
# Out:
#         itemId  categoryId
# 0       139578        1096
# 1       417975        1096
# 2       291805        1096
# 3       396921        1096
# 4       159257        1096
# ...        ...         ...
# 184042  384760         527
# 184043  386702         527
# 184044  384854         527
# 184045  128776         654
# 184046  128777         654
#
# [184047 rows x 2 columns]

# %%
prod = pd.read_csv('data/products.csv', sep=';')
prod
# Out:
#         itemId  pricelog2                       product.name.tokens
# 0            1         10           4875,776,56689,18212,18212,4896
# 1        69585          6               7583,18117,41805,41805,2371
# 2        90939          6                604,18117,41805,41805,2371
# 3        69586          0               2936,18117,41805,41805,2371
# 4        30029          7                    4668,41805,41805,56652
# ...        ...        ...                                       ...
# 184042  381997          8            134345,135203,3583,2886,103395
# 184043  402737          9  527890,527815,527815,183393,277935,19123
# 184044  388028         10                 527953,15027,15027,527952
# 184045  424367          9          360922,528327,52648,52648,514247
# 184046  387467          9           17260,130714,130714,3344,109312
#
# [184047 rows x 3 columns]

# %%
click = pd.read_csv('data/train-clicks.csv', sep=';')
click
# Out:
#          queryId  timeframe  itemId
# 0              1   16338861   24857
# 1          46255   16404912   30792
# 2          46689    3831948    8252
# 3          46731   16273568   33969
# 4          46748    4058493    7837
# ...          ...        ...     ...
# 1127759   980493     630896   42906
# 1127760   980493     641403   33312
# 1127761   980493      49028   33312
# 1127762   980493     573532    5227
# 1127763   980503     132863   13296
#
# [1127764 rows x 3 columns]

# %%
view = pd.read_csv('data/train-item-views.csv', sep=';')
view
# Out:
#          sessionId    userId  itemId  timeframe   eventdate
# 0                1       NaN   81766     526309  2016-05-09
# 1                1       NaN   31331    1031018  2016-05-09
# 2                1       NaN   32118     243569  2016-05-09
# 3                1       NaN    9654      75848  2016-05-09
# 4                1       NaN   32627    1112408  2016-05-09
# ...            ...       ...     ...        ...         ...
# 1235375     600684       NaN   42906     632853  2016-04-14
# 1235376     600684       NaN   33312     643522  2016-04-14
# 1235377     600684       NaN   33312      52621  2016-04-14
# 1235378     600684       NaN    5227     575276  2016-04-14
# 1235379     600687  249347.0   13296     135288  2016-02-16
#
# [1235380 rows x 5 columns]

# %%
purchases = pd.read_csv('data/train-purchases.csv', sep=';')
purchases
# Out:
#        sessionId   userId   timeframe   eventdate  ordernumber  itemId
# 0            150  18278.0    17100868  2016-05-06        16421   25911
# 1            151      NaN     6454547  2016-05-06        16290  175874
# 2            156      7.0  1721689387  2016-05-27        21173   35324
# 3            179      NaN      343001  2016-05-09        16924   31233
# 4            246     34.0     2311046  2016-05-09        16936   34677
# ...          ...      ...         ...         ...          ...     ...
# 18020     600131      NaN     3674676  2016-03-18         5675   40804
# 18021     600250      NaN     4943513  2016-05-21        19629   33777
# 18022     600432      NaN      205120  2016-04-25        13928   17176
# 18023     600432      NaN      205120  2016-04-25        13928   13662
# 18024     600661      NaN      582323  2016-05-15        18363  379345
#
# [18025 rows x 6 columns]

# %%
queries = pd.read_csv('data/train-queries.csv', sep=';')
queries
# Out:
# /tmp/ipykernel_421432/325745989.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   queries = pd.read_csv('data/train-queries.csv', sep=';')
#         queryId  sessionId    userId  timeframe  duration   eventdate  \
# 0             1          1       NaN   16327074       311  2016-05-09
# 1             2          2       NaN     705527       314  2016-05-09
# 2             3          3       NaN          0       502  2016-05-09
# 3             4          4       NaN          0      1092  2016-05-09
# 4             5          5       NaN     102700       266  2016-05-09
# ...         ...        ...       ...        ...       ...         ...
# 923122   980499     600685       NaN          0       407  2016-05-11
# 923123   980500      13265       NaN     361805      1203  2016-04-04
# 923124   980501     286379       NaN     953967      3789  2016-04-07
# 923125   980502     600686  249346.0          0      1581  2016-05-15
# ...

# %%
view_df = view.groupby('itemId').size()

# %%
view_df
# Out:
# itemId
# 1          2
# 2         41
# 3         22
# 4          3
# 6          9
#           ..
# 728310     1
# 728889     1
# 731658     1
# 732098     1
# 733848     2
# Length: 122993, dtype: int64

# %%
view_df[2]
# Out:
# 41

# %%
dir(view_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
view_df.keys()
# Out:
# Int64Index([     1,      2,      3,      4,      6,      7,      9,     10,
#                 11,     12,
#             ...
#             722600, 724353, 726916, 726936, 727403, 728310, 728889, 731658,
#             732098, 733848],
#            dtype='int64', name='itemId', length=122993)

# %%
prod['product.name.tokens']
# Out:
# 0                  4875,776,56689,18212,18212,4896
# 1                      7583,18117,41805,41805,2371
# 2                       604,18117,41805,41805,2371
# 3                      2936,18117,41805,41805,2371
# 4                           4668,41805,41805,56652
#                             ...
# 184042              134345,135203,3583,2886,103395
# 184043    527890,527815,527815,183393,277935,19123
# 184044                   527953,15027,15027,527952
# 184045            360922,528327,52648,52648,514247
# 184046             17260,130714,130714,3344,109312
# Name: product.name.tokens, Length: 184047, dtype: object

# %%
len(purchases)
# Out:
# 18025

# %%
# Find the queries that led to the purchase
purch = purchases.iloc[0]
possible_queries = queries.loc[queries['sessionId'] == purch['sessionId']]
for index, query in possible_queries.iterrows():
    if str(purch['itemId']) in query['items'].split(','):
        print(query['queryId'])
# Out:
# 152
# 45531
# 45664

# %%
p = purchases.copy()
p
# Out:
#        sessionId   userId   timeframe   eventdate  ordernumber  itemId
# 0            150  18278.0    17100868  2016-05-06        16421   25911
# 1            151      NaN     6454547  2016-05-06        16290  175874
# 2            156      7.0  1721689387  2016-05-27        21173   35324
# 3            179      NaN      343001  2016-05-09        16924   31233
# 4            246     34.0     2311046  2016-05-09        16936   34677
# ...          ...      ...         ...         ...          ...     ...
# 18020     600131      NaN     3674676  2016-03-18         5675   40804
# 18021     600250      NaN     4943513  2016-05-21        19629   33777
# 18022     600432      NaN      205120  2016-04-25        13928   17176
# 18023     600432      NaN      205120  2016-04-25        13928   13662
# 18024     600661      NaN      582323  2016-05-15        18363  379345
#
# [18025 rows x 6 columns]

# %%
d = p.groupby(['ordernumber']).size()
d
# Out:
# ordernumber
# 2        1
# 4        1
# 5        4
# 7        2
# 8        1
#         ..
# 22812    1
# 22813    1
# 22814    1
# 22816    1
# 22817    1
# Length: 13506, dtype: int64

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
# ...
#   Using cached kiwisolver-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached fonttools-4.29.0-py3-none-any.whl (895 kB)
# ...
#   Using cached Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(d, log=True)
# Out:
# (array([1.3101e+04, 2.9500e+02, 6.6000e+01, 2.6000e+01, 7.0000e+00,
#         6.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([ 1. ,  3.1,  5.2,  7.3,  9.4, 11.5, 13.6, 15.7, 17.8, 19.9, 22. ]),
#  <BarContainer object of 10 artists>)
